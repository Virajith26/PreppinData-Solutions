# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %%
f = pd.read_csv('PD 2023 Wk 1 Input.csv')
f
# Out:
#     Transaction Code  Value  Customer Code  Online or In-Person  \
# 0    DTB-716-679-576   1448         100001                    2
# 1     DS-795-814-303   7839         100001                    2
# 2    DSB-807-592-406   5520         100005                    1
# 3     DS-367-545-264   7957         100007                    2
# 4    DSB-474-374-857   5375         100000                    2
# ..               ...    ...            ...                  ...
# 360  DTB-116-439-102   6708         100001                    1
# 361   DS-849-981-514   8500         100000                    2
# 362   DS-726-686-279   9455         100006                    2
# 363   DS-551-937-380    475         100002                    1
# 364   DS-976-542-770   7364         100009                    1
#
#         Transaction Date
# 0    20/03/2023 00:00:00
# 1    15/11/2023 00:00:00
# 2    14/07/2023 00:00:00
# 3    18/08/2023 00:00:00
# 4    26/08/2023 00:00:00
# ..                   ...
# ...

# %% [markdown]
# Split the Transaction Code to extract the letters at the start of the transaction code. Rename the new field with the Bank code 'Bank'

# %%
t1 = pd.DataFrame(list(f['Transaction Code'].str.split(pat="-")),columns=['Bank','c1','c2','c3'])
t1
# Out:
#     Bank   c1   c2   c3
# 0    DTB  716  679  576
# 1     DS  795  814  303
# 2    DSB  807  592  406
# 3     DS  367  545  264
# 4    DSB  474  374  857
# ..   ...  ...  ...  ...
# 360  DTB  116  439  102
# 361   DS  849  981  514
# 362   DS  726  686  279
# 363   DS  551  937  380
# 364   DS  976  542  770
#
# [365 rows x 4 columns]

# %%
f2 = pd.concat([f,t1['Bank']],axis = 1)
f2
# Out:
#     Transaction Code  Value  Customer Code  Online or In-Person  \
# 0    DTB-716-679-576   1448         100001                    2
# 1     DS-795-814-303   7839         100001                    2
# 2    DSB-807-592-406   5520         100005                    1
# 3     DS-367-545-264   7957         100007                    2
# 4    DSB-474-374-857   5375         100000                    2
# ..               ...    ...            ...                  ...
# 360  DTB-116-439-102   6708         100001                    1
# 361   DS-849-981-514   8500         100000                    2
# 362   DS-726-686-279   9455         100006                    2
# 363   DS-551-937-380    475         100002                    1
# 364   DS-976-542-770   7364         100009                    1
#
#         Transaction Date Bank
# 0    20/03/2023 00:00:00  DTB
# 1    15/11/2023 00:00:00   DS
# 2    14/07/2023 00:00:00  DSB
# 3    18/08/2023 00:00:00   DS
# 4    26/08/2023 00:00:00  DSB
# ...

# %% [markdown]
# Rename the values in the Online or In-person field, Online of the 1 values and In-Person for the 2 values.

# %%
f2['OOnline or In-Person'] = f2['Online or In-Person'].apply(
    lambda x: 'Online' if x == 1 else 'In-person'
)
f2
# Out:
#     Transaction Code  Value  Customer Code  Online or In-Person  \
# 0    DTB-716-679-576   1448         100001                    2
# 1     DS-795-814-303   7839         100001                    2
# 2    DSB-807-592-406   5520         100005                    1
# 3     DS-367-545-264   7957         100007                    2
# 4    DSB-474-374-857   5375         100000                    2
# ..               ...    ...            ...                  ...
# 360  DTB-116-439-102   6708         100001                    1
# 361   DS-849-981-514   8500         100000                    2
# 362   DS-726-686-279   9455         100006                    2
# 363   DS-551-937-380    475         100002                    1
# 364   DS-976-542-770   7364         100009                    1
#
#         Transaction Date Bank OOnline or In-Person
# 0    20/03/2023 00:00:00  DTB            In-person
# 1    15/11/2023 00:00:00   DS            In-person
# ...

# %% [markdown]
# Change the date to be the day of the week

# %%
f2['Transaction Only Date'] = pd.to_datetime(f2['Transaction Date']).dt.day_name()
f2
# Out:
#     Transaction Code  Value  Customer Code  Online or In-Person  \
# 0    DTB-716-679-576   1448         100001                    2
# 1     DS-795-814-303   7839         100001                    2
# 2    DSB-807-592-406   5520         100005                    1
# 3     DS-367-545-264   7957         100007                    2
# 4    DSB-474-374-857   5375         100000                    2
# ..               ...    ...            ...                  ...
# 360  DTB-116-439-102   6708         100001                    1
# 361   DS-849-981-514   8500         100000                    2
# 362   DS-726-686-279   9455         100006                    2
# 363   DS-551-937-380    475         100002                    1
# 364   DS-976-542-770   7364         100009                    1
#
#         Transaction Date Bank OOnline or In-Person Transaction Only Date
# 0    20/03/2023 00:00:00  DTB            In-person                Monday
# ...

# %%
final_f = f2.drop(['Transaction Date','Online or In-Person','Transaction Code'],axis=1)
final_f.rename(columns = {'OOnline or In-Person':'Online or In-Person',
                          'Transaction Only Date':'Transaction Date' },inplace=True)
final_f
# Out:
#      Value  Customer Code Bank Online or In-Person Transaction Date
# 0     1448         100001  DTB           In-person           Monday
# 1     7839         100001   DS           In-person        Wednesday
# 2     5520         100005  DSB              Online           Friday
# 3     7957         100007   DS           In-person           Friday
# 4     5375         100000  DSB           In-person         Saturday
# ..     ...            ...  ...                 ...              ...
# 360   6708         100001  DTB              Online           Sunday
# 361   8500         100000   DS           In-person           Sunday
# 362   9455         100006   DS           In-person           Sunday
# 363    475         100002   DS              Online           Friday
# 364   7364         100009   DS              Online           Sunday
#
# [365 rows x 5 columns]

# %% [markdown]
# OUTPUT 1: Total Values of Transactions by each bank

# %%
output1 = pd.DataFrame(final_f.groupby(['Bank']).sum()).reset_index().loc[:,['Bank','Value']]
output1
# Out:
# <ipython-input-82-e54c9bac7a20>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   output1 = pd.DataFrame(final_f.groupby(['Bank']).sum()).reset_index().loc[:,['Bank','Value']]
#   Bank   Value
# 0   DS  653940
# 1  DSB  530489
# 2  DTB  618238

# %% [markdown]
# 2. Total Values by Bank, Day of the Week and Type of Transaction (Online or In-Person)

# %%
output2 = final_f.groupby(['Bank','Transaction Date','Online or In-Person']).sum().reset_index()
output2
# Out:
#    Bank Transaction Date Online or In-Person  Value  Customer Code
# 0    DS           Friday           In-person  50925        1000049
# 1    DS           Friday              Online  61713        1200065
# 2    DS           Monday           In-person  50810        1200041
# 3    DS           Monday              Online  34668         800041
# 4    DS         Saturday           In-person  41141         800042
# 5    DS         Saturday              Online  64362        1400074
# 6    DS           Sunday           In-person  70291        1400079
# 7    DS           Sunday              Online  40022         700037
# 8    DS         Thursday           In-person  39805         800042
# 9    DS         Thursday              Online  11448         200015
# 10   DS          Tuesday           In-person  42519         700028
# 11   DS          Tuesday              Online  41709        1000039
# 12   DS        Wednesday           In-person  63957        1000049
# ...

# %%
output3 = final_f.groupby(['Bank','Customer Code']).sum().reset_index()
output3
# Out:
# <ipython-input-88-2f9c71cb2d47>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   output3 = final_f.groupby(['Bank','Customer Code']).sum().reset_index()
#    Bank  Customer Code  Value
# 0    DS         100000  57909
# 1    DS         100001  53063
# 2    DS         100002  69803
# 3    DS         100003  25482
# 4    DS         100004  63315
# 5    DS         100005  39668
# 6    DS         100006  77636
# 7    DS         100007  76190
# 8    DS         100008  56400
# 9    DS         100009  56581
# 10   DS         100010  77893
# 11  DSB         100000  27585
# 12  DSB         100001  67856
# 13  DSB         100002  27936
# 14  DSB         100003  58154
# 15  DSB         100004  39003
# 16  DSB         100005  56396
# 17  DSB         100006  32333
# 18  DSB         100007  29702
# ...

# %% [markdown]
# Printing the DataFrames:

# %%
output1.to_csv('output1.csv',index=False)
output2.to_csv('output2.csv',index=False)
output3.to_csv('output3.csv',index=False)
